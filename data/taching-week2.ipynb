# %%
randoms[0, 0:100].shape
# Out:
# (2,)

# %%
arr = np.arange(10000000)
start = time.time()
arr_squared = arr ** 2
print("NumPy time:", time.time() - start)
# Out:
# NumPy time: 2.371973752975464

# %%
import time

lst = list(range(10000000))
start = time.time()
lst_squared = [i**2 for i in lst]
print("Python list time:", time.time() - start)

# %%
import numpy as np

a = np.array([1, 2, 3, 4, 5])
print(a)

b = np.array([[1, 2], [3, 4]])
print(b)

zeros = np.zeros((3,3))
ones = np.ones((2,4))
randoms = np.random.rand(2,2)
# Out:
# [1 2 3 4 5]
# [[1 2]
#  [3 4]]

# %%
print(a.shape)
print(a.ndim)
print(a.size)
print(a.dtype)
print(a[1:4])
# Out:
# (5,)
# 1
# 5
# int64
# [2 3 4]
